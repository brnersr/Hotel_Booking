# %% [markdown]
# ## HOTEL BOOKING PROJECT- APRIL 2024

# %% [markdown]
# ### _DATA ANALYSIS IN MICROSOFT POWER BI ON HOTEL BOOKING DATABASE_

# %% [markdown]
# # Hotel Booking Performance Report

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/hotelbooking_pic/HB1.png"
Image(filename=file_path)

# %% [markdown]
# Comment:
#
# * Count of Booking: There were 75 billion bookings.
# * Cancelled Bookings: Out of these, 44 billion were cancelled.
# * Total Revenue: The total revenue generated was 8.82 million.
# * Average Room Value: The average value of a room was 117.35.
# * Total Number of Guests: 146 billion guests were recorded.
# * Average Days Stayed: The average stay duration was 3 days.
#
# * Summer: Generated the highest revenue with 3.3 million.
# * Weekdays: Accounted for 73.62% of the total revenue.
# * Adults: Comprise the majority of the customer base with 92.25%.
# * Portugal (PRT): 21 billion bookings.
# * Type A having the highest at 52 billion and others with lower counts.
# * City Hotels: Generated 6.084 billion, accounting for 68.98% of the total room value.

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/hotelbooking_pic/HB1_1.png"
Image(filename=file_path)

# %% [markdown]
# Selected Year:2015
#
# Overall Performance:
#
# Number of Reservations: 4,520. This means that the hotel received a total of 4,520 reservations during 2015. A low number may indicate that the hotel struggled to attract customers during that year.
#
# Canceled Reservations: 1,645. The cancellation rate is quite high (36.4%). This may indicate that the hotel's cancellation policies are not attractive enough for customers or that there are problems with customer satisfaction.
#
# Total Revenue: 462.83 B. This refers to the hotel's total revenue from bookings. A high revenue indicates that the hotel's room rates may be above average. However, the low number of total bookings may raise questions about the sustainability of this revenue.
#
# Average Room Value: 102.40. This is the average price charged for each room. A high room value may indicate that the hotel offers luxury services or that its target audience is high-income customers.
#
# Total Number of Guests: 9114. This shows the total number of guests the hotel welcomes throughout the year. We can assume an average of 2 guests per booking. This may indicate that the hotel is preferred by families or couples.
#
# Average Length of Stay: 4 days. Indicates that customers stay at the hotel for an average of 4 days. This indicates that the hotel is an ideal stop for a vacation or business trip.
#
# Income Distribution (by Season):
# Fall: 0.23 M (49.11% of income).
# Summer: 0.19 M (40.05% of income).
# Winter: 0.05 M (10.84% of revenue).
# Fall and summer are the most profitable seasons for the hotel. In the winter season there is a significant drop in revenue, indicating that the hotel is in low demand during the winter season. Possible reasons could be that the services offered by the hotel are not suitable for winter tourism or the location is not attractive during the winter season.
#
# Revenue Breakdown by Week Groups:
# Weekdays: 71.67% of revenue.
# High weekday revenues may indicate that the hotel is preferred for business travel or is close to business centers.
#
# By Customer Accommodation Type,
# Adults %91.29.
# The percentage of adult customers is quite high. This may indicate that the hotel is not attractive for families with children or that there are not enough facilities for children.
#
# By Top 5 Most Booked Countries,
# The high number of reservations from Portugal and Spain may indicate that the hotel is focusing on promotional activities in these countries or that tourists from these countries prefer the hotel.
#
# Popular Room Types:
# The reservation rates of various room types are shown. Type A rooms seem to be the most popular.
#
# Room Value by Hotel Type:
# Resort Hotels: 228.71 B (49.41% of revenue).
# City Hotels: 234.12 B (50.59% of revenue).
# Revenue is almost evenly split between city hotels and resort hotels. This indicates that the hotel has a strong presence in both city and resort areas.

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/hotelbooking_pic/HB2.png"
Image(filename=file_path)

# %% [markdown]
# Based on this information,
# In 2016, there was a significant increase in revenue, but in 2017 there was a decline. This may indicate that the hotel had a successful marketing strategy or special campaign in 2016, but was unable to sustain this performance in 2017.
#
# 2015 has a generally low revenue trend.
# 2016 saw high revenues, peaking especially in the summer months (June-August).
# 2017 has a more balanced revenue distribution compared to 2016, but overall lower compared to 2016.
# These monthly trends indicate that the hotel is more popular in the summer months and experiences a drop in revenue during the winter months. Also, the high revenue growth in 2016 may indicate that a particular marketing strategy was successful and the hotel was successful in attracting customers during these periods.
#
# These growth rates indicate that the hotel had a great success in 2016, but was unable to sustain this success. A decline in 2017 may indicate that the market may have reached saturation or that competition has increased.
#
# These rates indicate that the hotel experienced significant growth, especially in January and May, but had a more modest growth rate in other months. The high growth rate in January may indicate increased bookings due to the New Year holidays.
#
# The fact that online and offline travel agencies are the largest source of revenue indicates that the hotel relies heavily on these channels and attracts customers through these channels. Other channels have lower revenues.
#
# Success in 2016: The hotel achieved high revenues in 2016 with a successful marketing strategy or special campaigns. These strategies should be analyzed and sustainability should be ensured.
#
# Decline in 2017: The reasons for the decline in 2017 should be analyzed; possible reasons such as increased competition, market saturation or problems in internal operations should be investigated.
#
# Seasonal Revenue Increase: The hotel generates the highest revenue in the summer months. By creating special campaigns or attractive packages for the winter months, low revenue during these periods can be increased.
#
# Marketing Channels: Online and offline travel agencies generate the highest revenue. Strategies should be developed for these channels and the hotel's presence in these channels should be strengthened. The performance of other channels can also be improved and diversification can be achieved.

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/hotelbooking_pic/HB3.png"
Image(filename=file_path)

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/hotelbooking_pic/HB4.png"
Image(filename=file_path)
